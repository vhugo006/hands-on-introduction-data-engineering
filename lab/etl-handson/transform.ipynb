# %%
from datetime import date
import pandas as pd

# %%
df = pd.read_csv('manual-extract-data.csv')
# Out:
#           Domain          Type  \
# 0        .abbott       generic
# 1       .abogado       generic
# 2            .ac  country-code
# 3       .academy       generic
# 4    .accountant       generic
# ..           ...           ...
# 914         .zip       generic
# 915          .zm  country-code
# 916        .zone       generic
# 917     .zuerich       generic
# 918          .zw  country-code
#
#                                Sponsoring Organisation
# 0                            Abbott Laboratories, Inc.
# 1                    Top Level Domain Holdings Limited
# 2    Network Information Center (AC Domain Registry...
# 3                                       Half Oaks, LLC
# 4                               dot Accountant Limited
# ..                                                 ...
# 914                      Charleston Road Registry Inc.
# 915  Zambia Information and Communications Technolo...
# 916                                   Outer Falls, LLC
# 917                   Kanton Zürich (Canton of Zurich)
# 918  Postal and Telecommunications Regulatory Autho...
#
# [919 rows x 3 columns]

# %%
df['Type'].unique()
generic_type_df = df[df['Type'] == "generic"]

generic_type_df
# Out:
#            Domain     Type            Sponsoring Organisation
# 0         .abbott  generic          Abbott Laboratories, Inc.
# 1        .abogado  generic  Top Level Domain Holdings Limited
# 3        .academy  generic                     Half Oaks, LLC
# 4     .accountant  generic             dot Accountant Limited
# 5    .accountants  generic                     Knob Town, LLC
# ..            ...      ...                                ...
# 910     .yokohama  generic                 GMO Registry, Inc.
# 911      .youtube  generic      Charleston Road Registry Inc.
# 914          .zip  generic      Charleston Road Registry Inc.
# 916         .zone  generic                   Outer Falls, LLC
# 917      .zuerich  generic   Kanton Zürich (Canton of Zurich)
#
# [590 rows x 3 columns]

# %%
today = date.today()
generic_type_df['Date'] = today.strftime('%Y-%m-%d')
generic_type_df
# Out:
# /tmp/ipykernel_511351/3454764738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   generic_type_df['Date'] = today.strftime('%Y-%m-%d')
#            Domain     Type            Sponsoring Organisation        Date
# 0         .abbott  generic          Abbott Laboratories, Inc.  2023-12-26
# 1        .abogado  generic  Top Level Domain Holdings Limited  2023-12-26
# 3        .academy  generic                     Half Oaks, LLC  2023-12-26
# 4     .accountant  generic             dot Accountant Limited  2023-12-26
# 5    .accountants  generic                     Knob Town, LLC  2023-12-26
# ..            ...      ...                                ...         ...
# 910     .yokohama  generic                 GMO Registry, Inc.  2023-12-26
# 911      .youtube  generic      Charleston Road Registry Inc.  2023-12-26
# 914          .zip  generic      Charleston Road Registry Inc.  2023-12-26
# 916         .zone  generic                   Outer Falls, LLC  2023-12-26
# 917      .zuerich  generic   Kanton Zürich (Canton of Zurich)  2023-12-26
#
# [590 rows x 4 columns]

# %%
generic_type_df.to_csv('manual-extract-data.csv', index=False)
